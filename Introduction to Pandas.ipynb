# %% [markdown]
# # The Famous Machine Learning Libraries In Python

# %% [markdown]
# ## 2- Introduction to Pandas

# %% [markdown]
# > **Pandas** is an open source Python library for data analysis. Pandas makes Python great for analysis.

# %%
#Let's bring pandas
import pandas as pd

# %% [markdown]
# At the very basic level, Pandas objects can be thought of as enhanced versions of NumPy structured arrays in which the rows and columns are identified with labels rather than simple integer indices.
#
# There are **three** core Pandas data structures. They are:
#
# > Series - A pandas Series is a one-dimensional array of indexed data.
#
# > Dataframe -  The DataFrame can be thought of either as a generalization of a NumPy array, or as a specialization of a Python dictionary.
#
# > Index -  This Index object is an interesting structure in itself, and it can be thought of as an ordered set.

# %% [markdown]
# ### 2.1 Series

# %%
s=pd.Series([1,2,3,4,6])
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    6
# dtype: int64

# %%
s.head()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    6
# dtype: int64

# %% [markdown]
# ### 2.2 DataFrame

# %%
from pandas import DataFrame

# %% [markdown]
# ### 2.3 Manipulation of tabular data

# %% [markdown]
# > in this part we will discuss a different way to upload and manipulate data

# %% [markdown]
# ### A- Reading a CSV file

# %%
data = pd.read_csv('TP_2_datset_mushrooms (2).csv')
data.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color   ...   stalk-surface-below-ring  \
# 0            c         n          k   ...                          s
# 1            c         b          k   ...                          s
# 2            c         b          n   ...                          s
# 3            c         n          n   ...                          s
# 4            w         b          k   ...                          s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# ...

# %%
data.describe()
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   8124      8124        8124      8124    8124  8124            8124
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color   ...   stalk-surface-below-ring  \
# count          8124      8124       8124   ...                       8124
# unique            2         2         12   ...                          4
# top               c         b          b   ...                          s
# freq           6812      5612       1728   ...                       4936
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    8124                   8124      8124       8124
# ...

# %%
data.dtypes
# Out:
# class                       object
# cap-shape                   object
# cap-surface                 object
# cap-color                   object
# bruises                     object
# odor                        object
# gill-attachment             object
# gill-spacing                object
# gill-size                   object
# gill-color                  object
# stalk-shape                 object
# stalk-root                  object
# stalk-surface-above-ring    object
# stalk-surface-below-ring    object
# stalk-color-above-ring      object
# stalk-color-below-ring      object
# veil-type                   object
# veil-color                  object
# ring-number                 object
# ring-type                   object
# spore-print-color           object
# population                  object
# habitat                     object
# dtype: object

# %%
data.shape
# Out:
# (8124, 23)

# %%
data.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
#head return the 5 top rows 
data.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color   ...   stalk-surface-below-ring  \
# 0            c         n          k   ...                          s
# 1            c         b          k   ...                          s
# 2            c         b          n   ...                          s
# 3            c         n          n   ...                          s
# 4            w         b          k   ...                          s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# ...

# %%
data.head(20)
# Out:
#    class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0      p         x           s         n       t    p               f
# 1      e         x           s         y       t    a               f
# 2      e         b           s         w       t    l               f
# 3      p         x           y         w       t    p               f
# 4      e         x           s         g       f    n               f
# 5      e         x           y         y       t    a               f
# 6      e         b           s         w       t    a               f
# 7      e         b           y         w       t    l               f
# 8      p         x           y         w       t    p               f
# 9      e         b           s         y       t    a               f
# 10     e         x           y         y       t    l               f
# 11     e         x           y         y       t    a               f
# ...

# %%
#  We access a specific column in the dataset by referring to its name inside square braces.
data['population']
# Out:
# 0       s
# 1       n
# 2       n
# 3       s
# 4       a
# 5       n
# 6       n
# 7       s
# 8       v
# 9       s
# 10      n
# 11      s
# 12      s
# 13      v
# 14      a
# 15      y
# 16      a
# 17      s
# 18      s
# 19      s
# 20      s
# 21      v
# 22      s
# 23      n
# 24      s
# 25      v
# 26      n
# 27      n
# 28      y
# 29      v
#        ..
# 8094    n
# 8095    c
# 8096    n
# 8097    v
# 8098    v
# 8099    s
# 8100    v
# 8101    v
# 8102    c
# 8103    c
# 8104    v
# 8105    v
# 8106    v
# 8107    c
# 8108    v
# 8109    n
# 8110    v
# 8111    n
# 8112    v
# 8113    v
# 8114    c
# 8115    v
# 8116    v
# 8117    v
# 8118    v
# 8119    c
# 8120    v
# 8121    c
# 8122    v
# 8123    c
# Name: population, Length: 8124, dtype: object

# %%
# we can also add another column to the table by copying a culumn that exist in the same dataset
data['people']=data.population+data.habitat
data.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ...   stalk-color-above-ring  \
# 0            c         n          k  ...                        w
# 1            c         b          k  ...                        w
# 2            c         b          n  ...                        w
# 3            c         n          n  ...                        w
# 4            w         b          k  ...                        w
#
#   stalk-color-below-ring veil-type veil-color ring-number ring-type  \
# 0                      w         p          w           o         p
# ...

# %%
var_1=data.iloc[:,1:6]
var_1
# Out:
#      cap-shape cap-surface cap-color bruises odor
# 0            x           s         n       t    p
# 1            x           s         y       t    a
# 2            b           s         w       t    l
# 3            x           y         w       t    p
# 4            x           s         g       f    n
# 5            x           y         y       t    a
# 6            b           s         w       t    a
# 7            b           y         w       t    l
# 8            x           y         w       t    p
# 9            b           s         y       t    a
# 10           x           y         y       t    l
# 11           x           y         y       t    a
# 12           b           s         y       t    a
# 13           x           y         w       t    p
# 14           x           f         n       f    n
# 15           s           f         g       f    n
# 16           f           f         w       f    n
# 17           x           s         n       t    p
# ...

# %%
# we can sort the dataset refering to a spécifique column
data.odor.sort_values(ascending=False)
data.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ...   stalk-color-above-ring  \
# 0            c         n          k  ...                        w
# 1            c         b          k  ...                        w
# 2            c         b          n  ...                        w
# 3            c         n          n  ...                        w
# 4            w         b          k  ...                        w
#
#   stalk-color-below-ring veil-type veil-color ring-number ring-type  \
# 0                      w         p          w           o         p
# ...

# %%
data.sort_values('people')
data.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ...   stalk-color-above-ring  \
# 0            c         n          k  ...                        w
# 1            c         b          k  ...                        w
# 2            c         b          n  ...                        w
# 3            c         n          n  ...                        w
# 4            w         b          k  ...                        w
#
#   stalk-color-below-ring veil-type veil-color ring-number ring-type  \
# 0                      w         p          w           o         p
# ...

# %%
data.sort_values(['odor','people'])
data.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ...   stalk-color-above-ring  \
# 0            c         n          k  ...                        w
# 1            c         b          k  ...                        w
# 2            c         b          n  ...                        w
# 3            c         n          n  ...                        w
# 4            w         b          k  ...                        w
#
#   stalk-color-below-ring veil-type veil-color ring-number ring-type  \
# 0                      w         p          w           o         p
# ...

# %%
# we can drop a column into the table by reffering it's name

data.drop('people',axis=1,inplace=True)
data.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color   ...   stalk-surface-below-ring  \
# 0            c         n          k   ...                          s
# 1            c         b          k   ...                          s
# 2            c         b          n   ...                          s
# 3            c         n          n   ...                          s
# 4            w         b          k   ...                          s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# ...

# %%
data.drop(['class','odor'],axis=1,inplace=True)
data.head()
# Out:
#   cap-shape cap-surface cap-color bruises gill-attachment gill-spacing  \
# 0         x           s         n       t               f            c
# 1         x           s         y       t               f            c
# 2         b           s         w       t               f            c
# 3         x           y         w       t               f            c
# 4         x           s         g       f               f            w
#
#   gill-size gill-color stalk-shape stalk-root   ...    \
# 0         n          k           e          e   ...
# 1         b          k           e          c   ...
# 2         b          n           e          c   ...
# 3         n          n           e          e   ...
# 4         b          k           t          e   ...
#
#   stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# 0                        s                      w                      w
# ...

# %% [markdown]
# >we can also access to a files by specifiying thier path location

# %%
import os

# %%
# specify the path and put it in a variable
path_2=os.getcwd()+"C:\\Users\\lenovo\\Downloads\\exo1.txt"
#load the dataset from path
data_2=pd.read_csv(path_2,header='None',names=['population','profit'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-4a22e20ad84d> in <module>()
#       2 path_2=os.getcwd()+"C:\\Users\\lenovo\\Downloads\\exo1.txt"
#       3 #load the dataset from path
# ----> 4 data_2=pd.read_csv(path_2,header='None',names=['population','profit'])
#
# ...

# %% [markdown]
# #### B- Reading table from URL

# %%
# 1 we are creating a variable called unfo 
# 2 then reading data into that variable from url
import pandas as pd
unfo = pd.read_table('http://bit.ly/uforeports', sep=',')
unfo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
